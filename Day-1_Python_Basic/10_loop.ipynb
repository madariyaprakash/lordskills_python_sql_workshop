# %% [markdown]
# ***WHILE LOOP***
#
# - Executes as long as condition is True.
# - Condition checked before every iteration

# %%
i = 1 
while i < 5:
    i += 1
    if i ==3:
        continue
    print(i)
# Out:
# 2
# 4
# 5

# %% [markdown]
# ***FOR LOOP***
#
# Used to iterate over sequences:
# - list
# - tuple
# - string
# - range
# - dictionary

# %% [markdown]
# ***break vs continue***
# - `break` - Terminates the loop immediately. Control moves outside the loop.
# - `continue` - Skips the current iteration. Loop continues with next iteration.

# %%
# mistake
# i = 0

# while i < 5:
#     if i == 2:
#         continue   # Infinite loop (i never increments)
#     print(i)
#     i += 1
