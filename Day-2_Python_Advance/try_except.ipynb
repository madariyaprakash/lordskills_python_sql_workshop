# %% [markdown]
# # try-except-finally

# %%
#10/0

try:
    result = 10/0
    print(result)
except ZeroDivisionError as e:
    print(f"An error occurred-{e}")
except ZeroDivisionError as e:
    print(f"An error occurred-{e}")
finally:
    print("thank you")
# Out:
# An error occurred-division by zero
# thank you
